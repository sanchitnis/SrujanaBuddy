# %%
import os

file_path = r'd:\Github\SrujanaBuddy\review\srujanabuddy-leadership-demo-v1.0.md'

with open(file_path, 'r', encoding='utf-8') as f:
    content = f.read()

# Revert <div class="mermaid"> to ```mermaid
content = content.replace('<div class="mermaid">', '```mermaid')
# Revert </div> to ```
content = content.replace('</div>', '```')

with open(file_path, 'w', encoding='utf-8') as f:
    f.write(content)

print("Restored standard mermaid code blocks.")
